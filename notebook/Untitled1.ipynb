# %%
# !pip install faker
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 14.5 MB/s eta 0:00:0031m16.4 MB/s eta 0:00:01
# ...

# %%
# import pandas as pd
# import numpy as np
# import random

# # SEED para reprodutibilidade
# random.seed(42)
# np.random.seed(42)

# # Nomes separados por gênero
# nomes_femininos = ['Ana', 'Carla', 'Elisa', 'Giovana', 'Isabela', 'Karen', 'Mariana', 'Olivia',
#                    'Quésia', 'Sara', 'Ursula', 'Wendy', 'Yara', 'Amanda', 'Diana', 'Flávia']

# nomes_masculinos = ['Bruno', 'Daniel', 'Fernando', 'Henrique', 'João', 'Lucas', 'Nicolas', 'Pedro',
#                     'Rafael', 'Thiago', 'Vinicius', 'Xande', 'Zeca', 'Caio', 'Eduardo', 'Gustavo']

# # Embaralhar os nomes
# random.shuffle(nomes_femininos)
# random.shuffle(nomes_masculinos)

# # Função para calcular tempo 3 km
# def calcular_tempo(sexo, idade, peso):
#     tempo_base = 10
#     penalidade_idade = (idade - 20) * 0.1
#     penalidade_peso = (peso - 50) * 0.05
#     bonus_sexo = -1 if sexo == 'M' else 0
#     ruido = np.random.normal(0, 0.7)
#     tempo = tempo_base + penalidade_idade + penalidade_peso + bonus_sexo + ruido
#     return round(np.clip(tempo, 10, 20), 2)

# # Gerar dados
# dados = []
# for _ in range(32):
#     sexo = random.choice(['F', 'M'])
#     idade = random.randint(20, 50)
#     peso = random.randint(50, 75) if sexo == 'F' else random.randint(65, 110)
    
#     # Nome coerente com sexo
#     if sexo == 'F':
#         nome = nomes_femininos.pop()
#     else:
#         nome = nomes_masculinos.pop()
    
#     tempo = calcular_tempo(sexo, idade, peso)
#     dados.append([nome, sexo, idade, peso, tempo])

# # Criar DataFrame
# df = pd.DataFrame(dados, columns=['Nome', 'Sexo', 'Idade', 'Peso', 'Tempo_3km'])

# # Visualizar
# print(df)



import pandas as pd
import numpy as np
import random
from faker import Faker

# SEED para reprodutibilidade
random.seed(42)
np.random.seed(42)
fake.seed_instance(42)

# Inicializar o Faker com localização pt_BR
fake = Faker('pt_BR')

# Função para calcular tempo
def calcular_tempo(sexo, idade, peso):
    tempo_base = 12
    penalidade_idade = (idade - 20) * 0.1
    penalidade_peso = (peso - 50) * 0.1
    bonus_sexo = -1 if sexo == 'M' else 0
    ruido = np.random.normal(0, 0.7)
    tempo = tempo_base + penalidade_idade + penalidade_peso + bonus_sexo + ruido
    return round(np.clip(tempo, 10, 20), 2)

# Gerar dados
dados = []
for _ in range(32):
    sexo = random.choice(['F', 'M'])
    if sexo == 'F':
        nome = fake.name_female()
        peso = random.randint(50, 75)
    else:
        nome = fake.name_male()
        peso = random.randint(60, 110)
    
    idade = random.randint(20, 50)
    tempo = calcular_tempo(sexo, idade, peso)
    dados.append([nome, sexo, idade, peso, tempo])

# Criar DataFrame
df = pd.DataFrame(dados, columns=['Nome', 'Sexo', 'Idade', 'Peso', 'Tempo_3km'])

# Visualizar
print(df)
# Out:
#                         Nome Sexo  Idade  Peso  Tempo_3km
# 0                Eloá Macedo    F     43    50      14.65
# 1             José das Neves    M     27    75      14.10
# 2              Júlia Barbosa    F     23    73      15.05
# 3              Esther Vieira    F     33    68      16.17
# 4         Antonella da Cunha    F     22    50      12.04
# 5           Catarina Freitas    F     36    57      14.14
# 6            Lorena da Costa    F     26    67      15.41
# 7           Dr. Asafe da Luz    M     34    74      15.34
# 8    Marcos Vinicius Costela    M     44    60      14.07
# 9          Sra. Nina Pereira    F     33    72      15.88
# 10            Heitor Pereira    M     24    77      13.78
# 11             Natália Cunha    F     30    74      15.07
# 12          Stella Rodrigues    F     32    52      13.57
# 13          Isabela Carvalho    F     47    61      14.46
# 14              Enrico Abreu    M     28    98      15.39
# ...
