# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %%
data = {
    "idade": [25, 22, 60,40 , 35, 50, 65],
    "colesterol alto": [0, 1, 0, 0, 1, 1, 0],
    "encaminhar": [0, 0, 1, 0, 1, 1, 1]
}

df = pd.DataFrame(data)
print(df)
#x_train=df.drop(['encaminhar'],axis=1)
y_train=df['encaminhar']
# Out:
#    idade  colesterol alto  encaminhar
# 0     25                0           0
# 1     22                1           0
# 2     60                0           1
# 3     40                0           0
# 4     35                1           1
# 5     50                1           1
# 6     65                0           1

# %%
from sklearn.tree import DecisionTreeClassifier
model_tree1 = DecisionTreeClassifier (criterion = 'gini', random_state = 0)

model_tree1.fit(x_train, y_train)

py= model_tree1.predict(x_train)
py
# Out:
# array([0, 0, 1, 0, 1, 1, 1])

# %%
plt.figure(figsize=(20,10))
plot_tree(model_tree1, filled=True, feature_names=x_train.columns, class_names=['0', '1'])
plt.show()

# %%
model_tree2 = DecisionTreeClassifier(max_depth=1, random_state=0)
model_tree2.fit(x_train, y_train)
plt.figure(figsize=(10, 6))
plot_tree(model_tree2, filled=True, feature_names=x_train.columns, class_names=['0', '1'])
plt.show()

# %%
from sklearn.metrics import mean_squared_error

GI=1-((3/7)**2 +(4/7)**2)
lado1=1-((3/4)** 2+(1/4)**2)
lado2=1-((0/3)**2+(3/3)**2)
print(lado1,lado2,GI)
# Out:
# 0.375 0.0 0.48979591836734704
